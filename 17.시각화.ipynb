# %%
import matplotlib as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.font_manager as fm
for i in fm.fontManager.ttflist:
    if i.name.find('Gulim') != -1:
        print(i.name)
# Out:
# Gulim
# New Gulim

# %%
# 폰트 지정
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim'
rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
plt.title('클래스와오브젝트')
plt.xlabel('클래스')
plt.ylabel('오브젝트')
# Out:
# Text(0, 0.5, '오브젝트')

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
d1 = anscombe[anscombe['dataset'] == 'I']
d2 = anscombe[anscombe['dataset'] == 'II']
d3 = anscombe[anscombe['dataset'] == 'III']
d4 = anscombe[anscombe['dataset'] =='IV']

# %%
plt.plot(d1['x'], d1['y'], 'o')

# %%
plt.plot(d2['x'], d2['y'], 'o')

# %%
plt.plot(d3['x'], d3['y'], 'x')

# %%
plt.subplot(2,2, 1)
plt.plot(d1['x'], d1['y'], 'o')
plt.subplot(2,2, 2)
plt.plot(d2['x'], d2['y'], 'o')
plt.subplot(2,2, 3)
plt.plot(d3['x'], d3['y'], 'x')
plt.subplot(2,2, 4)
plt.plot(d4['x'], d4['y'], 'o')

# %%
dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

plt.figure(figsize=(10, 6))
plt.title('10월간 주식 가격')
plt.xlabel('Date')
plt.ylabel('price')
plt.ylim(96, 110)
plt.plot(dates, prices, marker='o',label='종가')
plt.legend()
plt.grid(True)

# %%
plt.subplot(1,2, 1)
plt.plot(dates,prices,marker='o',color='green')
plt.xticks(rotation=30)
  # 라벨이 보이도록 설정

plt.subplot(1,2, 2)
plt.bar(dates,prices,color='orange')
plt.xticks(rotation=30)

# plt.savefig('./data/plt-ex', dpi=300, bbox_inches='tight')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, '2024-10-01'),
#   Text(1, 0, '2024-10-02'),
#   Text(2, 0, '2024-10-03'),
#   Text(3, 0, '2024-10-04'),
#   Text(4, 0, '2024-10-05')])

# %%
import numpy as np
data = np.random.randn(50).cumsum()
plt.plot(data)

# %%
plt.hist(np.random.randn(100),bins=20,color='k')
# Out:
# (array([ 2.,  1.,  2.,  3.,  7.,  7.,  6.,  4.,  6., 15.,  5.,  9.,  6.,
#          8.,  3.,  6.,  2.,  4.,  1.,  3.]),
#  array([-2.25262176, -2.03996319, -1.82730463, -1.61464607, -1.4019875 ,
#         -1.18932894, -0.97667037, -0.76401181, -0.55135325, -0.33869468,
#         -0.12603612,  0.08662244,  0.29928101,  0.51193957,  0.72459813,
#          0.9372567 ,  1.14991526,  1.36257383,  1.57523239,  1.78789095,
#          2.00054952]),
#  <BarContainer object of 20 artists>)

# %%
plt.subplot(1,3, 1)
plt.bar(dates,prices,color='orange')
plt.xticks(rotation=30)

plt.subplot(1,3, 2)
data = np.random.randn(50).cumsum()
plt.plot(data)

plt.subplot(1,3, 3)
import numpy as np

plt.hist(np.random.randn(100),bins=20,color='k')
# Out:
# (array([ 3.,  0.,  2.,  3.,  5., 10.,  9., 14., 18.,  7., 12.,  4.,  5.,
#          3.,  4.,  0.,  0.,  0.,  0.,  1.]),
#  array([-2.59562158, -2.29055329, -1.985485  , -1.68041671, -1.37534843,
#         -1.07028014, -0.76521185, -0.46014357, -0.15507528,  0.14999301,
#          0.45506129,  0.76012958,  1.06519787,  1.37026615,  1.67533444,
#          1.98040273,  2.28547102,  2.5905393 ,  2.89560759,  3.20067588,
#          3.50574416]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # 새로운 데이터셋

# %%
import seaborn as sns
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 히스토 그램
plt.hist(data = tips_df,x='total_bill',bins=20)
# Out:
# (array([ 1.,  6., 13., 29., 31., 37., 28., 23., 18., 13., 10.,  9.,  5.,
#          7.,  3.,  4.,  1.,  2.,  3.,  1.]),
#  array([ 3.07 ,  5.457,  7.844, 10.231, 12.618, 15.005, 17.392, 19.779,
#         22.166, 24.553, 26.94 , 29.327, 31.714, 34.101, 36.488, 38.875,
#         41.262, 43.649, 46.036, 48.423, 50.81 ]),
#  <BarContainer object of 20 artists>)

# %%
fig = plt.figure(figsize=(12, 5))  # 그래프 전체 크기 지정
axes1 = fig.add_subplot(1,2, 1)  # total_bill
axes2 = fig.add_subplot(1,2, 2)  # tips
axes1.hist(data=tips_df,x='total_bill', bins=20)
axes2.hist(data=tips_df,x='tip', bins=20)
plt.tight_layout()
plt.show()

# %%
# boxplot
fig = plt.figure(figsize=(12, 5))  # 그래프 전체 크기 지정
axes = fig.add_subplot(1,1, 1)  # total_bill
axes.boxplot(data=tips_df, x='total_bill')
plt.show()

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = plt.figure(figsize=(12, 5))  # 그래프 전체 크기 지정
axes = fig.add_subplot(1,1, 1)  # total_bill
axes.boxplot(
    x=[
    tips_df[tips_df['sex']=='Female']['total_bill'],
    tips_df[tips_df['sex']=='Male']['total_bill']
    ],
    labels=['Female','Male']
    )
plt.show()

# %%
fig = plt.figure(figsize=(12, 5))  # 그래프 전체 크기 지정
axes = fig.add_subplot(1,1, 1)  # total_bill
axes.boxplot(
    x=[
    tips_df[tips_df['smoker']=='Yes']['total_bill'],
    tips_df[tips_df['smoker']=='No']['total_bill']
    ],
    labels=['Yes','No']
    )
plt.show()

# %%
fig = plt.figure(figsize=(12, 5))  # 그래프 전체 크기 지정
axes = fig.add_subplot(1,1, 1)  # total_bill
axes.boxplot(
    x=[
    tips_df[tips_df['day']=='Thur']['tip'],
    tips_df[tips_df['day']=='Fri']['tip'],
    tips_df[tips_df['day']=='Sat']['tip'],
    tips_df[tips_df['day']=='Sun']['tip']
    ],
    labels=['Thur','Fri','Sat','Sun']
    )
plt.title('요일 별 팁')
plt.show()

# %%
tips_df.groupby(['day','time']).size()
# Out:
# day   time
# Thur  Lunch     61
#       Dinner     1
# Fri   Lunch      7
#       Dinner    12
# Sat   Lunch      0
#       Dinner    87
# Sun   Lunch      0
#       Dinner    76
# dtype: int64

# %%
# 산정도
fig = plt.figure()  # 그래프 전체 크기 지정
axes = fig.add_subplot(1,1, 1)
axes.scatter(
    tips_df['total_bill'],tips_df['tip']
)
plt.show()

# %%
colors = {'Female':'red','Male':'blue'}
# 다변량 표현
#성별에 따라 -색상
#값의 크기에 따라-점의 크기
fig = plt.figure()  # 그래프 전체 크기 지정
axes = fig.add_subplot(1,1,1)
axes.set_title('Total Bill vs Tip (Colored by Gender, Size = Party Size)')
axes.set_xlabel('Total Bill ($)')
axes.set_ylabel('Tip ($)')
axes.scatter(
    tips_df['total_bill'],
    tips_df['tip'],
    s=tips_df['size']**2*10,
    c=tips_df['sex'].map(colors)
)
plt.show()

# %%
colors = {'Female':'red','Male':'blue'}
tips_df['tips_pct'] = tips_df['tip']/tips_df['total_bill']
# 다변량 표현
#성별에 따라 -색상
#값의 크기에 따라-점의 크기
fig = plt.figure()  # 그래프 전체 크기 지정
axes = fig.add_subplot(1,1,1)
axes.set_title('Total Bill vs Tip (Colored by Gender, Size = Party Size)')
axes.set_xlabel('Total Bill ($)')
axes.set_ylabel('Tip ($)')

axes.scatter(
    tips_df['total_bill'],
    tips_df['tip'],
    s=tips_df['tips_pct']*1000,
    c=tips_df['sex'].map(colors),
    alpha= 0.5
)
plt.show()

# %%
tips_df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
# 파이 차트 -비율
# 성별 비율 비교
sex_counts = tips_df['sex'].value_counts()
fig =plt.figure()
axes = fig.add_subplot(1,1,1)
axes.pie(
    sex_counts,
    colors=['blue','red'],
    labels=sex_counts.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.show()
