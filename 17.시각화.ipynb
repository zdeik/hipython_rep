# %%
import matplotlib as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.font_manager as fm
for i in fm.fontManager.ttflist:
    if i.name.find('Gulim') != -1:
        print(i.name)
# Out:
# Gulim
# New Gulim

# %%
# 폰트 지정
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim'
rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
plt.title('클래스와오브젝트')
plt.xlabel('클래스')
plt.ylabel('오브젝트')
# Out:
# Text(0, 0.5, '오브젝트')

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
d1 = anscombe[anscombe['dataset'] == 'I']
d2 = anscombe[anscombe['dataset'] == 'II']
d3 = anscombe[anscombe['dataset'] == 'III']
d4 = anscombe[anscombe['dataset'] =='IV']

# %%
plt.plot(d1['x'], d1['y'], 'o')

# %%
plt.plot(d2['x'], d2['y'], 'o')

# %%
plt.plot(d3['x'], d3['y'], 'x')

# %%
dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

plt.figure(figsize=(10, 6))
plt.title('10월간 주식 가격')
plt.xlabel('Date')
plt.ylabel('price')
plt.ylim(96, 110)
plt.plot(dates, prices, marker='o',label='종가')
plt.legend()
plt.grid(True)

# %%
plt.subplot(1,2, 1)
plt.plot(dates,prices,marker='o',color='green')
plt.xticks(rotation=30)
  # 라벨이 보이도록 설정

plt.subplot(1,2, 2)
plt.bar(dates,prices,color='orange')
plt.xticks(rotation=30)

# plt.savefig('./data/plt-ex', dpi=300, bbox_inches='tight')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, '2024-10-01'),
#   Text(1, 0, '2024-10-02'),
#   Text(2, 0, '2024-10-03'),
#   Text(3, 0, '2024-10-04'),
#   Text(4, 0, '2024-10-05')])

# %%
import numpy as np
data = np.random.randn(50).cumsum()
plt.plot(data)

# %%
plt.hist(np.random.randn(100),bins=20,color='k')
# Out:
# (array([ 3.,  1.,  1.,  3.,  1.,  3.,  7.,  8.,  5., 11., 13.,  7.,  6.,
#          6.,  6.,  8.,  3.,  1.,  4.,  3.]),
#  array([-2.24865240e+00, -2.04412586e+00, -1.83959932e+00, -1.63507278e+00,
#         -1.43054624e+00, -1.22601970e+00, -1.02149316e+00, -8.16966623e-01,
#         -6.12440084e-01, -4.07913545e-01, -2.03387005e-01,  1.13953430e-03,
#          2.05666074e-01,  4.10192613e-01,  6.14719153e-01,  8.19245692e-01,
#          1.02377223e+00,  1.22829877e+00,  1.43282531e+00,  1.63735185e+00,
#          1.84187839e+00]),
#  <BarContainer object of 20 artists>)

# %%
plt.subplot(1,3, 1)
plt.bar(dates,prices,color='orange')
plt.xticks(rotation=30)

plt.subplot(1,3, 2)
data = np.random.randn(50).cumsum()
plt.plot(data)

plt.subplot(1,3, 3)
import numpy as np

plt.hist(np.random.randn(100),bins=20,color='k')
# Out:
# (array([ 4.,  4.,  3.,  9., 10., 10.,  7.,  7., 15.,  6.,  9.,  5.,  2.,
#          2.,  4.,  0.,  2.,  0.,  0.,  1.]),
#  array([-1.61083916, -1.38633274, -1.16182632, -0.9373199 , -0.71281348,
#         -0.48830706, -0.26380064, -0.03929422,  0.1852122 ,  0.40971862,
#          0.63422505,  0.85873147,  1.08323789,  1.30774431,  1.53225073,
#          1.75675715,  1.98126357,  2.20576999,  2.43027641,  2.65478283,
#          2.87928925]),
#  <BarContainer object of 20 artists>)

# %%
# scatter plot, 산점도
import numpy as np
import matplotlib.pyplot as plt

# 랜덤 좌표 50개 생성
x = np.random.randn(50)
y = np.random.randn(50)

plt.scatter(x, y, color='blue', alpha=0.6)  # 산점도 그리기
plt.title('랜덤 산점도')
plt.xlabel('X 값')
plt.ylabel('Y 값')
plt.grid(True)
plt.show()
