# %% [markdown]
# # HTTP 요청 방법

# %%
import requests
url = 'https://httpbin.org/get'
response = requests.get(url)
response.status_code
print(response.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68870d83-6b2324b605fe9c040e81d296"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/get"
# }

# %%
params = {
    'name': 'jungseok',
    'age': '26'
}
url = 'https://httpbin.org/get'
response = requests.get(url,params)
response.status_code
print(response.text)
# Out:
# {
#   "args": {
#     "age": "26",
#     "name": "jungseok"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68870e52-530daed45d22014f7dd8a48d"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/get?name=jungseok&age=26"
# }

# %%
# get?name=jungseok&age=26  --> 쿼리질의문

# %%
url = 'https://httpbin.org/post'
response = requests.post(url, data={'key': 'value'})
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68870fc1-7a9479f604c1bd9569e68d31"
#   },
#   "json": null,
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/post"
# }

# %%
response.json()['headers']['User-Agent']
# Out:
# 'python-requests/2.32.4'

# %%
url = 'https://httpbin.org/post'
response = requests.post(url, json={'key': 'value'})
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "{\"key\": \"value\"}",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "16",
#     "Content-Type": "application/json",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6887100f-68806bb2306350732a5884e3"
#   },
#   "json": {
#     "key": "value"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/post"
# }

# %%
url = 'https://httpbin.org/put'
response = requests.put(url, data={'key': 'value'})
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68871068-1985591c6dded5415671e012"
#   },
#   "json": null,
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/put"
# }

# %%
url = 'https://httpbin.org/patch'
response = requests.patch(url, data={'key': 'value'})
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-688710ed-691a9a94767defdb7bc68106"
#   },
#   "json": null,
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/patch"
# }
